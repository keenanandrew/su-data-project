# %% [markdown]
# A test Jupyter notebook, to work out how to store them on Github in a way that the underlying data is still accessible.

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
from scipy.stats import pearsonr, chi2_contingency
np.set_printoptions(suppress=True, precision = 2)

# %%
nba = pd.read_csv("https://raw.githubusercontent.com/keenanandrew/su-data-project/main/nba_games.csv")
nba.head(10)
# Out:
#         game_id  year_id  fran_id      opp_fran game_location  is_playoffs  \
# 0  194611010TRH     1947   Knicks       Huskies             A            0
# 1  194611020CHS     1947   Knicks         Stags             A            0
# 2  194611020PRO     1947  Celtics  Steamrollers             A            0
# 3  194611050BOS     1947  Celtics         Stags             H            0
# 4  194611070STB     1947   Knicks       Bombers             A            0
# 5  194611090DTF     1947  Celtics       Falcons             A            0
# 6  194611110NYK     1947   Knicks         Stags             H            0
# 7  194611130CHS     1947  Celtics         Stags             A            0
# 8  194611140STB     1947  Celtics       Bombers             A            0
# 9  194611160BOS     1947  Celtics       Huskies             H            0
#
#    pts  opp_pts game_result  forecast  point_diff
# 0   68       66           W  0.359935           2
# ...

# %% [markdown]
# Right. Let's try this again.

# %%
nba.describe()
# Out:
#             year_id   is_playoffs           pts       opp_pts      forecast  \
# count  24359.000000  24359.000000  24359.000000  24359.000000  24359.000000
# mean    1986.916581      0.077754    103.384663    102.438154      0.527805
# std       17.427172      0.267789     14.724792     14.812181      0.213054
# min     1947.000000      0.000000     43.000000     38.000000      0.024271
# 25%     1974.000000      0.000000     94.000000     93.000000      0.359191
# 50%     1988.000000      0.000000    103.000000    102.000000      0.533177
# 75%     2002.000000      0.000000    113.000000    112.000000      0.698763
# max     2015.000000      1.000000    173.000000    176.000000      0.976221
#
#          point_diff
# count  24359.000000
# mean       0.946508
# std       13.341020
# min      -62.000000
# 25%       -8.000000
# 50%        2.000000
# 75%       10.000000
# max       56.000000

# %%
nba.dtypes
# Out:
# game_id           object
# year_id            int64
# fran_id           object
# opp_fran          object
# game_location     object
# is_playoffs        int64
# pts                int64
# opp_pts            int64
# game_result       object
# forecast         float64
# point_diff         int64
# dtype: object

# %%
# sns.scatterplot(nba, x='pts', y = 'fran_id')

nba.fran_id.unique()

knicks_pts = nba.pts[nba.fran_id == 'Knicks']

knicks_avg = knicks_pts.mean()

print(knicks_avg)
# Out:
# 100.97018547408562

# %%
nba.head()

nba_2011 = nba[nba.year_id == 2011]

print(nba_2011)
# Out:
#             game_id  year_id  fran_id   opp_fran game_location  is_playoffs  \
# 22167  201010260BOS     2011  Celtics       Heat             H            0
# 22168  201010270CLE     2011  Celtics  Cavaliers             A            0
# 22169  201010270NJN     2011     Nets    Pistons             H            0
# 22170  201010270OKC     2011  Thunder      Bulls             H            0
# 22171  201010270SAS     2011    Spurs     Pacers             H            0
# ...             ...      ...      ...        ...           ...          ...
# 22608  201105170DAL     2011  Thunder  Mavericks             A            1
# 22609  201105190DAL     2011  Thunder  Mavericks             A            1
# 22610  201105210OKC     2011  Thunder  Mavericks             H            1
# 22611  201105230OKC     2011  Thunder  Mavericks             H            1
# 22612  201105250DAL     2011  Thunder  Mavericks             A            1
#
#        pts  opp_pts game_result  forecast  point_diff
# ...

# %%
nba_2011.describe()

nba_2011_pts_avg = nba_2011.pts.mean()

print(nba_2011_pts_avg)
# Out:
# 100.87443946188341
